# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path
import sys
import joblib
import optuna
import mlflow
import mlflow.sklearn

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import (
    accuracy_score, recall_score, roc_auc_score, confusion_matrix,
    mean_absolute_error, mean_squared_error, r2_score
)

from xgboost import XGBClassifier, XGBRegressor

# Access to src/
ROOT = Path("..").resolve()
sys.path.append(str(ROOT))

from src.mlflow_utils import setup_mlflow
from src.config import (
    DATA_PROCESSED_DIR, MODELS_DIR, THRESHOLD_HIGH_DELAY, RANDOM_STATE
)

setup_mlflow()

sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", None)

print("Notebook READY")
# Out:
# [MLflow] Creating experiment: us_flights_delay
# ──────────────────────────
# [MLflow] Tracking URI : file:/app/mlruns
# [MLflow] Experiment : us_flights_delay (ID=740368804610069892)
# ──────────────────────────
# Notebook READY

# %%
train = pd.read_csv(DATA_PROCESSED_DIR / "train.csv")
val   = pd.read_csv(DATA_PROCESSED_DIR / "val.csv")
test  = pd.read_csv(DATA_PROCESSED_DIR / "test.csv")

train.shape, val.shape, test.shape
# Out:
# ((119998, 31), (25714, 31), (25714, 31))

# %%
CATEGORICAL_COLS = ["carrier", "carrier_name", "airport", "airport_name"]

NUMERIC_COLS_CLF = [
    "year", "month", "arr_flights",
    "delay_rate", "avg_delay_per_flight",
    "cancel_rate", "divert_rate",
    "carrier_delay_per_flight",
    "weather_delay_per_flight",
    "nas_delay_per_flight",
    "security_delay_per_flight",
    "late_aircraft_delay_per_flight"
]

TARGET_CLF = "high_delay_risk"

NUMERIC_COLS_REG = [
    "year", "month", "arr_flights",
    "delay_rate",
    "cancel_rate", "divert_rate",
    "carrier_delay_per_flight",
    "weather_delay_per_flight",
    "nas_delay_per_flight",
    "security_delay_per_flight",
    "late_aircraft_delay_per_flight"
]

TARGET_REG = "avg_delay_per_flight"

# %%
cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

preprocessor_clf = ColumnTransformer([
    ("cat", cat_pipeline, CATEGORICAL_COLS),
    ("num", num_pipeline, NUMERIC_COLS_CLF)
])

preprocessor_reg = ColumnTransformer([
    ("cat", cat_pipeline, CATEGORICAL_COLS),
    ("num", num_pipeline, NUMERIC_COLS_REG)
])

# %%
def get_clf_data():
    return (
        train[CATEGORICAL_COLS + NUMERIC_COLS_CLF], train[TARGET_CLF],
        val[CATEGORICAL_COLS + NUMERIC_COLS_CLF],   val[TARGET_CLF],
        test[CATEGORICAL_COLS + NUMERIC_COLS_CLF],  test[TARGET_CLF]
    )

def get_reg_data():
    return (
        train[CATEGORICAL_COLS + NUMERIC_COLS_REG], train[TARGET_REG],
        val[CATEGORICAL_COLS + NUMERIC_COLS_REG],   val[TARGET_REG],
        test[CATEGORICAL_COLS + NUMERIC_COLS_REG],  test[TARGET_REG]
    )

def eval_reg(y_true, y_pred):
    return {
        "mae":  mean_absolute_error(y_true, y_pred),
        "rmse": np.sqrt(mean_squared_error(y_true, y_pred)),
        "r2":   r2_score(y_true, y_pred)
    }

# %%
X_train, y_train, X_val, y_val, X_test, y_test = get_clf_data()

log_reg = LogisticRegression(
    max_iter=1000,
    class_weight="balanced",
    random_state=RANDOM_STATE
)

pipe_logreg = Pipeline([
    ("preprocessor", preprocessor_clf),
    ("classifier", log_reg)
])

with mlflow.start_run(run_name="baseline_logreg"):
    pipe_logreg.fit(X_train, y_train)

    y_val_pred  = pipe_logreg.predict(X_val)
    y_val_proba = pipe_logreg.predict_proba(X_val)[:, 1]

    acc = accuracy_score(y_val, y_val_pred)
    rec = recall_score(y_val, y_val_pred)
    auc = roc_auc_score(y_val, y_val_proba)

    mlflow.log_params({"model":"logreg"})
    mlflow.log_metrics({"val_acc":acc,"val_rec":rec,"val_auc":auc})

    MODELS_DIR.mkdir(exist_ok=True)
    path_lr = MODELS_DIR/"logreg_baseline.joblib"
    joblib.dump(pipe_logreg, path_lr)
    mlflow.log_artifact(str(path_lr))

acc, rec, auc
# Out:
# (0.9979388659873999, 0.9973352464896997, 0.9999807826261374)

# %%
X_train_r, y_train_r, X_val_r, y_val_r, X_test_r, y_test_r = get_reg_data()

lin_reg = LinearRegression()

pipe_linreg = Pipeline([
    ("preprocessor", preprocessor_reg),
    ("regressor", lin_reg)
])

with mlflow.start_run(run_name="baseline_linreg"):
    pipe_linreg.fit(X_train_r, y_train_r)

    y_pred_val = pipe_linreg.predict(X_val_r)
    metrics = eval_reg(y_val_r, y_pred_val)

    mlflow.log_metrics(metrics)

    path_lr_reg = MODELS_DIR/"linreg_baseline.joblib"
    joblib.dump(pipe_linreg, path_lr_reg)
    mlflow.log_artifact(str(path_lr_reg))

metrics
# Out:
# {'mae': 2.283080104724543e-05,
#  'rmse': 0.00030452921911005497,
#  'r2': 0.9999999992069446}

# %%
XGB_CLF_SPACE = {
    "n_estimators": (300, 800),
    "max_depth": (3, 9),
    "learning_rate": (0.01, 0.2),
    "subsample": (0.6, 1.0),
    "colsample_bytree": (0.6, 1.0),
    "min_child_weight": (1, 12),
    "gamma": (0.0, 5.0)
}

# %%
def objective_xgb_clf(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", *XGB_CLF_SPACE["n_estimators"]),
        "max_depth": trial.suggest_int("max_depth", *XGB_CLF_SPACE["max_depth"]),
        "learning_rate": trial.suggest_float("learning_rate", *XGB_CLF_SPACE["learning_rate"], log=True),
        "subsample": trial.suggest_float("subsample", *XGB_CLF_SPACE["subsample"]),
        "colsample_bytree": trial.suggest_float("colsample_bytree", *XGB_CLF_SPACE["colsample_bytree"]),
        "min_child_weight": trial.suggest_int("min_child_weight", *XGB_CLF_SPACE["min_child_weight"]),
        "gamma": trial.suggest_float("gamma", *XGB_CLF_SPACE["gamma"]),
        "random_state": RANDOM_STATE,
        "n_jobs": -1,
        "eval_metric": "logloss"
    }

    model = XGBClassifier(**params)
    pipe = Pipeline([
        ("preprocessor", preprocessor_clf),
        ("classifier", model)
    ])

    pipe.fit(X_train, y_train)
    proba = pipe.predict_proba(X_val)[:, 1]
    return roc_auc_score(y_val, proba)

# %%
study_clf = optuna.create_study(direction="maximize")
study_clf.optimize(objective_xgb_clf, n_trials=25)

study_clf.best_params, study_clf.best_value
# Out:
# [I 2025-12-08 18:59:00,367] A new study created in memory with name: no-name-4a69cf96-911f-4775-b321-c7fabbb57405
# [I 2025-12-08 18:59:10,807] Trial 0 finished with value: 0.9999942257957546 and parameters: {'n_estimators': 714, 'max_depth': 3, 'learning_rate': 0.0173782807779963, 'subsample': 0.9359530623065841, 'colsample_bytree': 0.8496887646602237, 'min_child_weight': 8, 'gamma': 0.0075674527033159356}. Best is trial 0 with value: 0.9999942257957546.
# [I 2025-12-08 18:59:17,232] Trial 1 finished with value: 0.9999937633455814 and parameters: {'n_estimators': 434, 'max_depth': 9, 'learning_rate': 0.03956816555640904, 'subsample': 0.674202972408012, 'colsample_bytree': 0.6187126691505483, 'min_child_weight': 6, 'gamma': 4.02248632385139}. Best is trial 0 with value: 0.9999942257957546.
# [I 2025-12-08 18:59:24,932] Trial 2 finished with value: 0.9999940844915349 and parameters: {'n_estimators': 539, 'max_depth': 4, 'learning_rate': 0.07073493876122235, 'subsample': 0.8489160835264126, 'colsample_bytree': 0.8707972437862002, 'min_child_weight': 8, 'gamma': 0.2748623120393967}. Best is trial 0 with value: 0.9999942257957546.
# [I 2025-12-08 18:59:30,230] Trial 3 finished with value: 0.9999945148271128 and parameters: {'n_estimators': 357, 'max_depth': 5, 'learning_rate': 0.01984270223495944, 'subsample': 0.6465954411123072, 'colsample_bytree': 0.8475610912662946, 'min_child_weight': 8, 'gamma': 1.1558622888083359}. Best is trial 3 with value: 0.9999945148271128.
# [I 2025-12-08 18:59:38,692] Trial 4 finished with value: 0.9999947588980375 and parameters: {'n_estimators': 321, 'max_depth': 6, 'learning_rate': 0.014607890246738009, 'subsample': 0.7381679070211907, 'colsample_bytree': 0.9947685952715134, 'min_child_weight': 1, 'gamma': 1.1671282281921802}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 18:59:45,238] Trial 5 finished with value: 0.9999945276729509 and parameters: {'n_estimators': 605, 'max_depth': 9, 'learning_rate': 0.07421077370103182, 'subsample': 0.9128340024901404, 'colsample_bytree': 0.9672584573349783, 'min_child_weight': 11, 'gamma': 1.7567101686089766}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 18:59:50,733] Trial 6 finished with value: 0.9999945469417082 and parameters: {'n_estimators': 556, 'max_depth': 7, 'learning_rate': 0.14135681678205844, 'subsample': 0.8729169740216083, 'colsample_bytree': 0.896281904178259, 'min_child_weight': 12, 'gamma': 3.1209938321571467}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:01,265] Trial 7 finished with value: 0.999994354254136 and parameters: {'n_estimators': 746, 'max_depth': 7, 'learning_rate': 0.06314618571261144, 'subsample': 0.8830024223466131, 'colsample_bytree': 0.913747651126951, 'min_child_weight': 10, 'gamma': 0.2817261586642933}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:08,490] Trial 8 finished with value: 0.9999938404206103 and parameters: {'n_estimators': 722, 'max_depth': 3, 'learning_rate': 0.17112230434896222, 'subsample': 0.8141247665111742, 'colsample_bytree': 0.9111531837219318, 'min_child_weight': 11, 'gamma': 2.9988126096456136}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:15,486] Trial 9 finished with value: 0.9999944570208411 and parameters: {'n_estimators': 505, 'max_depth': 4, 'learning_rate': 0.029602822557952806, 'subsample': 0.61429422074199, 'colsample_bytree': 0.7703126066496153, 'min_child_weight': 2, 'gamma': 0.31061776179406475}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:20,898] Trial 10 finished with value: 0.9999921704616517 and parameters: {'n_estimators': 319, 'max_depth': 6, 'learning_rate': 0.013329561759538772, 'subsample': 0.7469457293553372, 'colsample_bytree': 0.7411544084005731, 'min_child_weight': 1, 'gamma': 1.9006979552019392}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:26,758] Trial 11 finished with value: 0.9999942386415928 and parameters: {'n_estimators': 620, 'max_depth': 7, 'learning_rate': 0.19834220833697477, 'subsample': 0.7681882288986746, 'colsample_bytree': 0.996831957813943, 'min_child_weight': 4, 'gamma': 3.1465830472094}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:31,157] Trial 12 finished with value: 0.9999943927916504 and parameters: {'n_estimators': 439, 'max_depth': 7, 'learning_rate': 0.11984907150521984, 'subsample': 0.9925245520317816, 'colsample_bytree': 0.9462094229920806, 'min_child_weight': 4, 'gamma': 4.113745379702177}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:38,073] Trial 13 finished with value: 0.999992754947287 and parameters: {'n_estimators': 444, 'max_depth': 6, 'learning_rate': 0.010397600922200186, 'subsample': 0.714848072392438, 'colsample_bytree': 0.6848326923526231, 'min_child_weight': 4, 'gamma': 4.8159715927703015}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:44,495] Trial 14 finished with value: 0.9999944634437603 and parameters: {'n_estimators': 592, 'max_depth': 8, 'learning_rate': 0.027303488968696887, 'subsample': 0.8197228468228739, 'colsample_bytree': 0.9964469154582004, 'min_child_weight': 12, 'gamma': 2.4304723825000414}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:51,394] Trial 15 finished with value: 0.9999941294519685 and parameters: {'n_estimators': 676, 'max_depth': 5, 'learning_rate': 0.1200351610503641, 'subsample': 0.712990148964251, 'colsample_bytree': 0.9099177931594875, 'min_child_weight': 6, 'gamma': 1.305488633805882}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:00:57,092] Trial 16 finished with value: 0.9999947267834421 and parameters: {'n_estimators': 384, 'max_depth': 8, 'learning_rate': 0.04716499012200653, 'subsample': 0.7765167003485908, 'colsample_bytree': 0.829145947796522, 'min_child_weight': 2, 'gamma': 3.2704851796620424}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:01:01,978] Trial 17 finished with value: 0.9999945533646272 and parameters: {'n_estimators': 376, 'max_depth': 8, 'learning_rate': 0.04561850783428765, 'subsample': 0.7617736492507816, 'colsample_bytree': 0.7971102905998823, 'min_child_weight': 2, 'gamma': 3.785051334404927}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:01:07,854] Trial 18 finished with value: 0.9999939945706681 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.025419910674290374, 'subsample': 0.7009644661852896, 'colsample_bytree': 0.7080604200171549, 'min_child_weight': 1, 'gamma': 0.8932529175958148}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:01:13,703] Trial 19 finished with value: 0.9999945983250608 and parameters: {'n_estimators': 387, 'max_depth': 5, 'learning_rate': 0.04487439197782582, 'subsample': 0.784809101592047, 'colsample_bytree': 0.6001319379467603, 'min_child_weight': 3, 'gamma': 2.173772124823861}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:01:18,657] Trial 20 finished with value: 0.9999943221395406 and parameters: {'n_estimators': 486, 'max_depth': 6, 'learning_rate': 0.0903761085000501, 'subsample': 0.7345927411271178, 'colsample_bytree': 0.8214950172955422, 'min_child_weight': 5, 'gamma': 4.8045741605814705}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:01:23,707] Trial 21 finished with value: 0.9999944827125175 and parameters: {'n_estimators': 384, 'max_depth': 5, 'learning_rate': 0.04456287702952071, 'subsample': 0.7925521639171272, 'colsample_bytree': 0.6268820705779793, 'min_child_weight': 3, 'gamma': 2.219077720371687}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:01:28,449] Trial 22 finished with value: 0.999994540518789 and parameters: {'n_estimators': 342, 'max_depth': 5, 'learning_rate': 0.03616208138631475, 'subsample': 0.7876875859773335, 'colsample_bytree': 0.6595906417163642, 'min_child_weight': 2, 'gamma': 2.773116440307299}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:01:33,110] Trial 23 finished with value: 0.9999946240167369 and parameters: {'n_estimators': 405, 'max_depth': 6, 'learning_rate': 0.05699735802394017, 'subsample': 0.8243707277657891, 'colsample_bytree': 0.7484119354047938, 'min_child_weight': 3, 'gamma': 3.495071522248768}. Best is trial 4 with value: 0.9999947588980375.
# [I 2025-12-08 19:01:41,875] Trial 24 finished with value: 0.9999947781667947 and parameters: {'n_estimators': 797, 'max_depth': 6, 'learning_rate': 0.057353619802128775, 'subsample': 0.8332287058274315, 'colsample_bytree': 0.7412708773687853, 'min_child_weight': 1, 'gamma': 3.472562210524953}. Best is trial 24 with value: 0.9999947781667947.
# ({'n_estimators': 797,
#   'max_depth': 6,
#   'learning_rate': 0.057353619802128775,
#   'subsample': 0.8332287058274315,
#   'colsample_bytree': 0.7412708773687853,
#   'min_child_weight': 1,
#   'gamma': 3.472562210524953},
#  0.9999947781667947)

# %%
best_clf_params = study_clf.best_params.copy()
best_clf_params.update({
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "eval_metric": "logloss"
})

xgb_clf = XGBClassifier(**best_clf_params)

pipe_xgb_clf = Pipeline([
    ("preprocessor", preprocessor_clf),
    ("classifier", xgb_clf)
])

with mlflow.start_run(run_name="xgb_classifier_optuna"):
    pipe_xgb_clf.fit(X_train, y_train)

    val_proba = pipe_xgb_clf.predict_proba(X_val)[:, 1]
    val_pred  = (val_proba >= 0.5).astype(int)

    metrics = {
        "acc": accuracy_score(y_val, val_pred),
        "rec": recall_score(y_val, val_pred),
        "auc": roc_auc_score(y_val, val_proba),
    }

    mlflow.log_params(best_clf_params)
    mlflow.log_metrics(metrics)

    path_clf = MODELS_DIR/"xgb_classifier_optuna.joblib"
    joblib.dump(pipe_xgb_clf, path_clf)
    mlflow.log_artifact(str(path_clf))

metrics
# Out:
# {'acc': 0.9987166524072489,
#  'rec': 0.998462642205596,
#  'auc': 0.9999947781667947}

# %%
XGB_REG_SPACE = XGB_CLF_SPACE  # même search space

# %%
def objective_xgb_reg(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", *XGB_REG_SPACE["n_estimators"]),
        "max_depth": trial.suggest_int("max_depth", *XGB_REG_SPACE["max_depth"]),
        "learning_rate": trial.suggest_float("learning_rate", *XGB_REG_SPACE["learning_rate"], log=True),
        "subsample": trial.suggest_float("subsample", *XGB_REG_SPACE["subsample"]),
        "colsample_bytree": trial.suggest_float("colsample_bytree", *XGB_REG_SPACE["colsample_bytree"]),
        "min_child_weight": trial.suggest_int("min_child_weight", *XGB_REG_SPACE["min_child_weight"]),
        "gamma": trial.suggest_float("gamma", *XGB_REG_SPACE["gamma"]),
        "random_state": RANDOM_STATE,
        "n_jobs": -1
    }

    model = XGBRegressor(**params)
    pipe = Pipeline([
        ("preprocessor", preprocessor_reg),
        ("regressor", model)
    ])

    pipe.fit(X_train_r, y_train_r)
    pred = pipe.predict(X_val_r)

    rmse = np.sqrt(mean_squared_error(y_val_r, pred))
    return -rmse  # minimisation

# %%
study_reg = optuna.create_study(direction="maximize")
study_reg.optimize(objective_xgb_reg, n_trials=25)

study_reg.best_params, study_reg.best_value
# Out:
# [I 2025-12-08 19:01:49,614] A new study created in memory with name: no-name-443a3424-92d5-441b-9252-1cc959d3a84a
# [I 2025-12-08 19:01:57,437] Trial 0 finished with value: -4.96137997691394 and parameters: {'n_estimators': 519, 'max_depth': 3, 'learning_rate': 0.020175292951666028, 'subsample': 0.9311059489476211, 'colsample_bytree': 0.7098096058189693, 'min_child_weight': 8, 'gamma': 2.886257968862437}. Best is trial 0 with value: -4.96137997691394.
# [I 2025-12-08 19:02:05,307] Trial 1 finished with value: -4.984388851248342 and parameters: {'n_estimators': 350, 'max_depth': 3, 'learning_rate': 0.027591805490018127, 'subsample': 0.8481882021081653, 'colsample_bytree': 0.6120942491941856, 'min_child_weight': 11, 'gamma': 0.39965313208868647}. Best is trial 0 with value: -4.96137997691394.
# [I 2025-12-08 19:02:30,971] Trial 2 finished with value: -5.036027133735411 and parameters: {'n_estimators': 609, 'max_depth': 9, 'learning_rate': 0.022399459460005718, 'subsample': 0.818177815027454, 'colsample_bytree': 0.825777590439788, 'min_child_weight': 11, 'gamma': 2.887557653482005}. Best is trial 0 with value: -4.96137997691394.
# [I 2025-12-08 19:02:40,022] Trial 3 finished with value: -4.987203737132173 and parameters: {'n_estimators': 498, 'max_depth': 6, 'learning_rate': 0.05120284659108405, 'subsample': 0.7147780923528912, 'colsample_bytree': 0.8920707482457464, 'min_child_weight': 4, 'gamma': 1.295501862489819}. Best is trial 0 with value: -4.96137997691394.
# [I 2025-12-08 19:02:52,574] Trial 4 finished with value: -5.012580352807262 and parameters: {'n_estimators': 535, 'max_depth': 7, 'learning_rate': 0.01174934690277381, 'subsample': 0.9209235472819273, 'colsample_bytree': 0.6176651454600546, 'min_child_weight': 10, 'gamma': 0.2954771164744113}. Best is trial 0 with value: -4.96137997691394.
# [I 2025-12-08 19:02:58,956] Trial 5 finished with value: -4.943207695061793 and parameters: {'n_estimators': 546, 'max_depth': 3, 'learning_rate': 0.022004134034303516, 'subsample': 0.9628099739513942, 'colsample_bytree': 0.7769270336593797, 'min_child_weight': 9, 'gamma': 1.031919451029718}. Best is trial 5 with value: -4.943207695061793.
# [I 2025-12-08 19:03:11,571] Trial 6 finished with value: -4.930658978891651 and parameters: {'n_estimators': 742, 'max_depth': 5, 'learning_rate': 0.011862410854811847, 'subsample': 0.8671714666027448, 'colsample_bytree': 0.9291847192641115, 'min_child_weight': 11, 'gamma': 0.1099561091651935}. Best is trial 6 with value: -4.930658978891651.
# [I 2025-12-08 19:03:17,905] Trial 7 finished with value: -4.820330862316192 and parameters: {'n_estimators': 572, 'max_depth': 3, 'learning_rate': 0.03763161531587402, 'subsample': 0.8316829019087199, 'colsample_bytree': 0.687404629380544, 'min_child_weight': 7, 'gamma': 2.767846206175637}. Best is trial 7 with value: -4.820330862316192.
# [I 2025-12-08 19:03:33,516] Trial 8 finished with value: -4.935857001093396 and parameters: {'n_estimators': 744, 'max_depth': 7, 'learning_rate': 0.016525996087046448, 'subsample': 0.6163513031841574, 'colsample_bytree': 0.7469933719537107, 'min_child_weight': 7, 'gamma': 4.542046582920686}. Best is trial 7 with value: -4.820330862316192.
# [I 2025-12-08 19:03:41,069] Trial 9 finished with value: -4.957848764796162 and parameters: {'n_estimators': 382, 'max_depth': 6, 'learning_rate': 0.02476538671782782, 'subsample': 0.8280234938516262, 'colsample_bytree': 0.7995789673333731, 'min_child_weight': 8, 'gamma': 3.9135403438524}. Best is trial 7 with value: -4.820330862316192.
# [I 2025-12-08 19:03:48,506] Trial 10 finished with value: -4.816941178904727 and parameters: {'n_estimators': 644, 'max_depth': 4, 'learning_rate': 0.13428495729238815, 'subsample': 0.7334001508323766, 'colsample_bytree': 0.6943378148645458, 'min_child_weight': 2, 'gamma': 2.0912677322545044}. Best is trial 10 with value: -4.816941178904727.
# [I 2025-12-08 19:03:56,041] Trial 11 finished with value: -4.787668899778117 and parameters: {'n_estimators': 634, 'max_depth': 4, 'learning_rate': 0.12082505362887964, 'subsample': 0.734740795571743, 'colsample_bytree': 0.6774786984125496, 'min_child_weight': 2, 'gamma': 2.0194140342543907}. Best is trial 11 with value: -4.787668899778117.
# [I 2025-12-08 19:04:05,748] Trial 12 finished with value: -4.699699863065641 and parameters: {'n_estimators': 661, 'max_depth': 5, 'learning_rate': 0.14630221812042393, 'subsample': 0.7303950258869595, 'colsample_bytree': 0.6735013733641545, 'min_child_weight': 1, 'gamma': 1.835710402034841}. Best is trial 12 with value: -4.699699863065641.
# [I 2025-12-08 19:04:14,471] Trial 13 finished with value: -4.633253365325228 and parameters: {'n_estimators': 665, 'max_depth': 5, 'learning_rate': 0.1993307949631522, 'subsample': 0.7373637391705539, 'colsample_bytree': 0.6443353874455423, 'min_child_weight': 1, 'gamma': 1.6937325634106157}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:04:23,956] Trial 14 finished with value: -5.229827498162035 and parameters: {'n_estimators': 696, 'max_depth': 5, 'learning_rate': 0.1963616033027634, 'subsample': 0.6423425301058429, 'colsample_bytree': 0.9985287165904924, 'min_child_weight': 4, 'gamma': 1.627872650863693}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:04:35,351] Trial 15 finished with value: -4.7773173659707755 and parameters: {'n_estimators': 788, 'max_depth': 5, 'learning_rate': 0.07570377809936771, 'subsample': 0.6908807713874645, 'colsample_bytree': 0.6380772166405928, 'min_child_weight': 1, 'gamma': 3.616253310861209}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:04:44,649] Trial 16 finished with value: -5.130510346801906 and parameters: {'n_estimators': 424, 'max_depth': 7, 'learning_rate': 0.19915377762750314, 'subsample': 0.7557579642615665, 'colsample_bytree': 0.6514760841408164, 'min_child_weight': 4, 'gamma': 0.9543922701316695}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:04:57,242] Trial 17 finished with value: -4.993646309344285 and parameters: {'n_estimators': 688, 'max_depth': 9, 'learning_rate': 0.0891144128266319, 'subsample': 0.7760451551311963, 'colsample_bytree': 0.7264818258330459, 'min_child_weight': 1, 'gamma': 2.1719143853361005}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:05:02,890] Trial 18 finished with value: -4.880382461816139 and parameters: {'n_estimators': 462, 'max_depth': 4, 'learning_rate': 0.1368316495096389, 'subsample': 0.6578039861647885, 'colsample_bytree': 0.8610396275219406, 'min_child_weight': 5, 'gamma': 1.541910126604088}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:05:12,810] Trial 19 finished with value: -4.795225442339302 and parameters: {'n_estimators': 673, 'max_depth': 5, 'learning_rate': 0.0628581319072033, 'subsample': 0.684195678923409, 'colsample_bytree': 0.6585419272587483, 'min_child_weight': 3, 'gamma': 3.4374443700127717}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:05:25,074] Trial 20 finished with value: -5.241744965461984 and parameters: {'n_estimators': 577, 'max_depth': 8, 'learning_rate': 0.10733220641976648, 'subsample': 0.7810355521125264, 'colsample_bytree': 0.7641087228252106, 'min_child_weight': 5, 'gamma': 0.7314894040950907}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:05:36,509] Trial 21 finished with value: -4.797399170224438 and parameters: {'n_estimators': 800, 'max_depth': 5, 'learning_rate': 0.09436794733878066, 'subsample': 0.6909123508311604, 'colsample_bytree': 0.6031727309505701, 'min_child_weight': 1, 'gamma': 4.979700335271045}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:05:49,284] Trial 22 finished with value: -4.85455091627543 and parameters: {'n_estimators': 783, 'max_depth': 6, 'learning_rate': 0.07310806477339996, 'subsample': 0.6014547237577487, 'colsample_bytree': 0.6443541922383254, 'min_child_weight': 1, 'gamma': 4.0017542376817925}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:05:57,652] Trial 23 finished with value: -5.005497022321045 and parameters: {'n_estimators': 731, 'max_depth': 4, 'learning_rate': 0.16067829966990646, 'subsample': 0.6985829946763737, 'colsample_bytree': 0.6375807824369135, 'min_child_weight': 2, 'gamma': 3.3741038868375814}. Best is trial 13 with value: -4.633253365325228.
# [I 2025-12-08 19:06:07,407] Trial 24 finished with value: -4.844152696966667 and parameters: {'n_estimators': 713, 'max_depth': 5, 'learning_rate': 0.07547189021733576, 'subsample': 0.6721764288540474, 'colsample_bytree': 0.728585804718963, 'min_child_weight': 3, 'gamma': 2.440412060750035}. Best is trial 13 with value: -4.633253365325228.
# ({'n_estimators': 665,
#   'max_depth': 5,
#   'learning_rate': 0.1993307949631522,
#   'subsample': 0.7373637391705539,
#   'colsample_bytree': 0.6443353874455423,
#   'min_child_weight': 1,
#   'gamma': 1.6937325634106157},
#  -4.633253365325228)

# %%
best_reg_params = study_reg.best_params.copy()
best_reg_params.update({
    "random_state": RANDOM_STATE,
    "n_jobs": -1
})

xgb_reg = XGBRegressor(**best_reg_params)

pipe_xgb_reg = Pipeline([
    ("preprocessor", preprocessor_reg),
    ("regressor", xgb_reg)
])

with mlflow.start_run(run_name="xgb_regressor_optuna"):
    pipe_xgb_reg.fit(X_train_r, y_train_r)

    y_pred_val = pipe_xgb_reg.predict(X_val_r)
    metrics = eval_reg(y_val_r, y_pred_val)

    mlflow.log_params(best_reg_params)
    mlflow.log_metrics(metrics)

    path_reg = MODELS_DIR/"xgb_regressor_optuna.joblib"
    joblib.dump(pipe_xgb_reg, path_reg)
    mlflow.log_artifact(str(path_reg))

metrics
# Out:
# {'mae': 0.5081514188601832,
#  'rmse': 4.633253365325228,
#  'r2': 0.8164232415805031}

# %%
print("TRAINING PIPELINE COMPLETE")
# Out:
# TRAINING PIPELINE COMPLETE
